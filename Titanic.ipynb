# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %% [markdown]
# # Dependencies

# %%
import tensorflow_decision_forests as tfdf
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import numpy as np

# %% [markdown]
# # Load the data

# %%
train_data = pd.read_csv('/kaggle/input/titanic/train.csv')
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_data = pd.read_csv('/kaggle/input/titanic/test.csv')
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # Prepare dataset

# %%
def preprocess(df):
    df = df.copy()
    
    def normalize_name(x):
        return " ".join([v.strip(",()[].\"'") for v in x.split(" ")])
    
    def ticket_number(x):
        return x.split(" ")[-1]
        
    def ticket_item(x):
        items = x.split(" ")
        if len(items) == 1:
            return "NONE"
        return "_".join(items[0:-1])
    
    df["Name"] = df["Name"].apply(normalize_name)
    df["Ticket_number"] = df["Ticket"].apply(ticket_number)
    df["Ticket_item"] = df["Ticket"].apply(ticket_item)                     
    return df
    
preprocessed_train_data = preprocess(train_data)
preprocessed_test_data = preprocess(test_data)



preprocessed_train_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 0                            Braund Mr Owen Harris    male  22.0      1
# 1  Cumings Mrs John Bradley Florence Briggs Thayer  female  38.0      1
# 2                             Heikkinen Miss Laina  female  26.0      0
# 3         Futrelle Mrs Jacques Heath Lily May Peel  female  35.0      1
# 4                           Allen Mr William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Ticket_number Ticket_item
# 0      0         A/5 21171   7.2500   NaN        S         21171         A/5
# 1      0          PC 17599  71.2833   C85        C         17599          PC
# 2      0  STON/O2. 3101282   7.9250   NaN        S       3101282    STON/O2.
# 3      0            113803  53.1000  C123        S        113803        NONE
# 4      0            373450   8.0500   NaN        S        373450        NONE

# %% [markdown]
# # EDA : Explore Data Analysis

# %%
women = preprocessed_train_data.loc[preprocessed_train_data.Sex == 'female']['Survived']
rate_women = sum(women)/len(women)

print(f'{rate_women}% of women survived')
# Out:
# 0.7420382165605095% of women survived

# %%
men = preprocessed_train_data.loc[preprocessed_train_data.Sex == 'male']['Survived']
rate_men = sum(men)/len(men)

print(f'{rate_men}% of men survived')
# Out:
# 0.18890814558058924% of men survived

# %%
input_features = list(preprocessed_train_data.columns)
input_features.remove('PassengerId')
input_features.remove('Ticket')
input_features.remove('Survived')

print(f'input features : {input_features}')
# Out:
# input features : ['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'Ticket_number', 'Ticket_item']

# %% [markdown]
# # Convert Pandas dataset to TensorFlow Dataset¶

# %%
def tokenize_names(features, labels=None):
    """Divite the names into tokens. TF-DF can consume text tokens natively."""
    features["Names"] = tf.strings.split(features["Name"])
    return features, labels

train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(preprocessed_train_data,label="Survived").map(tokenize_names)
test_ds =  tfdf.keras.pd_dataframe_to_tf_dataset(preprocessed_test_data).map(tokenize_names)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()

# %% [markdown]
# # Train model with default parameters

# %%
model = tfdf.keras.GradientBoostedTreesModel(
    verbose=0, # Very few logs
    features=[tfdf.keras.FeatureUsage(name=n) for n in input_features],
    exclude_non_specified_features=True, # Only use the features in "features"
    random_seed=1234,
)

model.fit(train_ds)

self_evaluation = model.make_inspector().evaluation()
print(f"Accuracy: {self_evaluation.accuracy} Loss:{self_evaluation.loss}")
# Out:
# W0000 00:00:1764070091.920761    2741 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1764070091.920807    2741 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1764070091.920811    2741 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1764070092.159576    2741 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1764070092.159608    2741 kernel.cc:783] Collect training examples
# I0000 00:00:1764070092.159628    2741 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1764070092.160008    2741 kernel.cc:401] Number of batches: 1
# I0000 00:00:1764070092.160029    2741 kernel.cc:402] Number of examples: 891
# I0000 00:00:1764070092.160560    2741 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1764070092.160917    2741 data_spec_inference.cc:354] 891 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1764070092.161099    2741 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1764070092.161296    2741 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1764070092.161652    2741 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 7 (58.3333%)
# 	NUMERICAL: 5 (41.6667%)
#
# Columns:
#
# CATEGORICAL: 7 (58.3333%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	4: "Name" CATEGORICAL has-dict vocab-size:1 num-oods:891 (100%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1764070092.161687    2741 kernel.cc:818] Configure learner
# W0000 00:00:1764070092.161983    2741 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1764070092.161997    2741 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1764070092.162000    2741 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1764070092.162037    2741 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 1234
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1764070092.162150    2741 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmpubr9m0zq/working_cache"
# num_threads: 4
# try_resume_training: true
#
# I0000 00:00:1764070092.162265    3183 kernel.cc:895] Train model
# I0000 00:00:1764070092.162414    3183 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070092.162430    3183 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1764070092.162908    3183 gradient_boosted_trees.cc:1230] 799 examples used for training and 92 examples used for validation
# I0000 00:00:1764070092.163410    3183 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070092.166583    3183 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.218856 train-accuracy:0.624531 valid-loss:1.311875 valid-accuracy:0.543478 [total:0.00s iter:0.00s]
# I0000 00:00:1764070092.169361    3183 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.135870 train-accuracy:0.624531 valid-loss:1.234170 valid-accuracy:0.543478 [total:0.01s iter:0.00s]
# I0000 00:00:1764070092.172195    3183 gradient_boosted_trees.cc:1634] Train tree 3/300 train-loss:1.067583 train-accuracy:0.799750 valid-loss:1.177798 valid-accuracy:0.728261 [total:0.01s iter:0.00s]
# I0000 00:00:1764070092.299311    3183 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.887458
# I0000 00:00:1764070092.299359    3183 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 54
# I0000 00:00:1764070092.301340    3183 gradient_boosted_trees.cc:279] Truncates the model to 25 tree(s) i.e. 25  iteration(s).
# I0000 00:00:1764070092.301599    3183 gradient_boosted_trees.cc:341] Final model num-trees:25 valid-loss:0.887458 valid-accuracy:0.815217
# I0000 00:00:1764070092.302192    3183 kernel.cc:926] Export model in log directory: /tmp/tmpubr9m0zq with prefix 53f9be33d5d54d66
# I0000 00:00:1764070092.303341    3183 kernel.cc:944] Save model in resources
# I0000 00:00:1764070092.304961    2741 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.887458
#
# Accuracy: 0.815217  CI95[W][0 1]
# ErrorRate: : 0.184783
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  47   3
# 2  14  28
# Total: 92
#
#
# I0000 00:00:1764070092.321006    2741 quick_scorer_extended.cc:927] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# I0000 00:00:1764070092.321193    2741 abstract_model.cc:1439] Engine "GradientBoostedTreesQuickScorerExtended" built
# Accuracy: 0.8152173757553101 Loss:0.887458324432373

# %% [markdown]
# # Predictions

# %%
def prediction(model, threshold=0.5):
    proba_survive = model.predict(test_ds, verbose=0)[:,0]
    return pd.DataFrame({
        "PassengerId": test_data["PassengerId"],
        "Survived": (proba_survive >= threshold).astype(int)
    })

predictions = prediction(model)

print(predictions.to_string())
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function InferenceCoreModel.make_predict_function.<locals>.predict_function_trained at 0x78dcb8d72de0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function InferenceCoreModel.make_predict_function.<locals>.predict_function_trained at 0x78dcb8d72de0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         0
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         1
# 29           921         0
# 30           922         0
# 31           923         0
# 32           924         1
# 33           925         0
# 34           926         0
# 35           927         0
# 36           928         0
# 37           929         0
# 38           930         0
# 39           931         1
# 40           932         0
# 41           933         0
# 42           934         0
# 43           935         1
# 44           936         1
# 45           937         0
# 46           938         0
# 47           939         0
# 48           940         1
# 49           941         1
# 50           942         0
# 51           943         0
# 52           944         1
# 53           945         1
# 54           946         0
# 55           947         0
# 56           948         0
# 57           949         0
# 58           950         0
# 59           951         1
# 60           952         0
# 61           953         0
# 62           954         0
# 63           955         1
# 64           956         0
# 65           957         1
# 66           958         1
# 67           959         0
# 68           960         0
# 69           961         1
# 70           962         1
# 71           963         0
# 72           964         0
# 73           965         0
# 74           966         1
# 75           967         0
# 76           968         0
# 77           969         1
# 78           970         0
# 79           971         1
# 80           972         1
# 81           973         0
# 82           974         0
# 83           975         0
# 84           976         0
# 85           977         0
# 86           978         1
# 87           979         1
# 88           980         1
# 89           981         1
# 90           982         1
# 91           983         0
# 92           984         1
# 93           985         0
# 94           986         0
# 95           987         0
# 96           988         1
# 97           989         0
# 98           990         1
# 99           991         0
# 100          992         1
# 101          993         0
# 102          994         0
# 103          995         0
# 104          996         1
# 105          997         0
# 106          998         0
# 107          999         0
# 108         1000         0
# 109         1001         0
# 110         1002         0
# 111         1003         1
# 112         1004         1
# 113         1005         1
# 114         1006         1
# 115         1007         0
# 116         1008         0
# 117         1009         1
# 118         1010         0
# 119         1011         1
# 120         1012         1
# 121         1013         0
# 122         1014         1
# 123         1015         0
# 124         1016         0
# 125         1017         1
# 126         1018         0
# 127         1019         1
# 128         1020         0
# 129         1021         0
# 130         1022         0
# 131         1023         0
# 132         1024         0
# 133         1025         0
# 134         1026         0
# 135         1027         0
# 136         1028         0
# 137         1029         0
# 138         1030         0
# 139         1031         0
# 140         1032         0
# 141         1033         1
# 142         1034         0
# 143         1035         0
# 144         1036         0
# 145         1037         0
# 146         1038         0
# 147         1039         0
# 148         1040         0
# 149         1041         0
# 150         1042         1
# 151         1043         0
# 152         1044         0
# 153         1045         0
# 154         1046         0
# 155         1047         0
# 156         1048         1
# 157         1049         1
# 158         1050         0
# 159         1051         0
# 160         1052         1
# 161         1053         1
# 162         1054         1
# 163         1055         0
# 164         1056         0
# 165         1057         0
# 166         1058         0
# 167         1059         0
# 168         1060         1
# 169         1061         0
# 170         1062         0
# 171         1063         0
# 172         1064         0
# 173         1065         0
# 174         1066         0
# 175         1067         1
# 176         1068         1
# 177         1069         0
# 178         1070         1
# 179         1071         1
# 180         1072         0
# 181         1073         0
# 182         1074         1
# 183         1075         0
# 184         1076         1
# 185         1077         0
# 186         1078         1
# 187         1079         0
# 188         1080         0
# 189         1081         0
# 190         1082         0
# 191         1083         0
# 192         1084         1
# 193         1085         0
# 194         1086         1
# 195         1087         0
# 196         1088         1
# 197         1089         1
# 198         1090         0
# 199         1091         0
# 200         1092         1
# 201         1093         1
# 202         1094         0
# 203         1095         1
# 204         1096         0
# 205         1097         0
# 206         1098         1
# 207         1099         0
# 208         1100         1
# 209         1101         0
# 210         1102         0
# 211         1103         0
# 212         1104         0
# 213         1105         1
# 214         1106         0
# 215         1107         0
# 216         1108         1
# 217         1109         0
# 218         1110         1
# 219         1111         0
# 220         1112         1
# 221         1113         0
# 222         1114         1
# 223         1115         0
# 224         1116         1
# 225         1117         0
# 226         1118         0
# 227         1119         1
# 228         1120         0
# 229         1121         0
# 230         1122         0
# 231         1123         1
# 232         1124         0
# 233         1125         0
# 234         1126         1
# 235         1127         0
# 236         1128         0
# 237         1129         0
# 238         1130         1
# 239         1131         1
# 240         1132         1
# 241         1133         1
# 242         1134         0
# 243         1135         0
# 244         1136         0
# 245         1137         0
# 246         1138         1
# 247         1139         0
# 248         1140         1
# 249         1141         0
# 250         1142         1
# 251         1143         0
# 252         1144         0
# 253         1145         0
# 254         1146         0
# 255         1147         0
# 256         1148         0
# 257         1149         0
# 258         1150         1
# 259         1151         0
# 260         1152         0
# 261         1153         0
# 262         1154         1
# 263         1155         1
# 264         1156         0
# 265         1157         0
# 266         1158         0
# 267         1159         0
# 268         1160         1
# 269         1161         0
# 270         1162         0
# 271         1163         0
# 272         1164         1
# 273         1165         1
# 274         1166         0
# 275         1167         1
# 276         1168         0
# 277         1169         0
# 278         1170         0
# 279         1171         0
# 280         1172         0
# 281         1173         1
# 282         1174         1
# 283         1175         0
# 284         1176         0
# 285         1177         0
# 286         1178         0
# 287         1179         0
# 288         1180         0
# 289         1181         0
# 290         1182         0
# 291         1183         1
# 292         1184         0
# 293         1185         0
# 294         1186         0
# 295         1187         0
# 296         1188         1
# 297         1189         0
# 298         1190         0
# 299         1191         0
# 300         1192         0
# 301         1193         0
# 302         1194         0
# 303         1195         0
# 304         1196         1
# 305         1197         1
# 306         1198         0
# 307         1199         1
# 308         1200         0
# 309         1201         0
# 310         1202         0
# 311         1203         0
# 312         1204         0
# 313         1205         0
# 314         1206         1
# 315         1207         1
# 316         1208         0
# 317         1209         0
# 318         1210         0
# 319         1211         0
# 320         1212         0
# 321         1213         0
# 322         1214         0
# 323         1215         0
# 324         1216         1
# 325         1217         0
# 326         1218         1
# 327         1219         0
# 328         1220         0
# 329         1221         0
# 330         1222         1
# 331         1223         1
# 332         1224         0
# 333         1225         1
# 334         1226         0
# 335         1227         0
# 336         1228         0
# 337         1229         0
# 338         1230         0
# 339         1231         0
# 340         1232         0
# 341         1233         0
# 342         1234         0
# 343         1235         1
# 344         1236         0
# 345         1237         1
# 346         1238         0
# 347         1239         0
# 348         1240         0
# 349         1241         1
# 350         1242         1
# 351         1243         0
# 352         1244         0
# 353         1245         0
# 354         1246         1
# 355         1247         0
# 356         1248         1
# 357         1249         0
# 358         1250         0
# 359         1251         0
# 360         1252         0
# 361         1253         1
# 362         1254         1
# 363         1255         0
# 364         1256         1
# 365         1257         0
# 366         1258         0
# 367         1259         0
# 368         1260         1
# 369         1261         0
# 370         1262         0
# 371         1263         1
# 372         1264         0
# 373         1265         0
# 374         1266         1
# 375         1267         1
# 376         1268         0
# 377         1269         0
# 378         1270         0
# 379         1271         0
# 380         1272         0
# 381         1273         0
# 382         1274         1
# 383         1275         1
# 384         1276         0
# 385         1277         1
# 386         1278         0
# 387         1279         0
# 388         1280         0
# 389         1281         0
# 390         1282         0
# 391         1283         1
# 392         1284         0
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         1
# 405         1297         0
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         0
# 410         1302         1
# 411         1303         1
# 412         1304         0
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0

# %% [markdown]
# # Hyperparameters tunning

# %%
tuner = tfdf.tuner.RandomSearch(num_trials=300)
tuner.choice("min_examples", [2, 5, 7, 10])
tuner.choice("categorical_algorithm", ["CART", "RANDOM"])

local_search_space = tuner.choice("growing_strategy", ["LOCAL"])
local_search_space.choice("max_depth", [3, 4, 5, 6, 8])

global_search_space = tuner.choice("growing_strategy", ["BEST_FIRST_GLOBAL"], merge=True)
global_search_space.choice("max_num_nodes", [16, 32, 64, 128, 256])

tuner.choice("shrinkage", [0.02, 0.05, 0.10, 0.15])
tuner.choice("num_candidate_attributes_ratio", [0.2, 0.5, 0.9, 1.0])


tuner.choice("split_axis", ["AXIS_ALIGNED"])
oblique_space = tuner.choice("split_axis", ["SPARSE_OBLIQUE"], merge=True)
oblique_space.choice("sparse_oblique_normalization",
                     ["NONE", "STANDARD_DEVIATION", "MIN_MAX"])
oblique_space.choice("sparse_oblique_weights", ["BINARY", "CONTINUOUS"])
oblique_space.choice("sparse_oblique_num_projections_exponent", [1.0, 1.5])

# Tune the model. Notice the `tuner=tuner`.
tuned_model = tfdf.keras.GradientBoostedTreesModel(tuner=tuner)
tuned_model.fit(train_ds, verbose=0)
# Out:
# Use /tmp/tmpg5m654ph as temporary training directory
# W0000 00:00:1764070092.610698    2741 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1764070092.610746    2741 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1764070092.610751    2741 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1764070092.859149    2741 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1764070092.859181    2741 kernel.cc:783] Collect training examples
# I0000 00:00:1764070092.859188    2741 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1764070092.859267    2741 kernel.cc:401] Number of batches: 1
# I0000 00:00:1764070092.859274    2741 kernel.cc:402] Number of examples: 891
# I0000 00:00:1764070092.860276    2741 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1764070092.860570    2741 data_spec_inference.cc:354] 891 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1764070092.861024    2741 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Names (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1764070092.861293    2741 data_spec_inference.cc:354] 673 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1764070092.861360    2741 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1764070092.861541    2741 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1764070092.862202    2741 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 15
#
# Number of columns by type:
# 	CATEGORICAL: 8 (53.3333%)
# 	NUMERICAL: 6 (40%)
# 	CATEGORICAL_SET: 1 (6.66667%)
#
# Columns:
#
# CATEGORICAL: 8 (53.3333%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	4: "Name" CATEGORICAL has-dict vocab-size:1 num-oods:891 (100%)
# 	9: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	11: "Ticket" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	12: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	13: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	14: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 6 (40%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	6: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	7: "PassengerId" NUMERICAL mean:446 min:1 max:891 sd:257.209
# 	8: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	10: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (6.66667%)
# 	5: "Names" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1764070092.862242    2741 kernel.cc:818] Configure learner
# W0000 00:00:1764070092.862566    2741 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1764070092.862581    2741 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1764070092.862586    2741 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1764070092.862643    2741 kernel.cc:831] Training config:
# learner: "HYPERPARAMETER_OPTIMIZER"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Names$"
# features: "^Parch$"
# features: "^PassengerId$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# metadata {
#   framework: "TF Keras"
# }
# [yggdrasil_decision_forests.model.hyperparameters_optimizer_v2.proto.hyperparameters_optimizer_config] {
#   base_learner {
#     learner: "GRADIENT_BOOSTED_TREES"
#     features: "^Age$"
#     features: "^Cabin$"
#     features: "^Embarked$"
#     features: "^Fare$"
#     features: "^Name$"
#     features: "^Names$"
#     features: "^Parch$"
#     features: "^PassengerId$"
#     features: "^Pclass$"
#     features: "^Sex$"
#     features: "^SibSp$"
#     features: "^Ticket$"
#     features: "^Ticket_item$"
#     features: "^Ticket_number$"
#     label: "^__LABEL$"
#     task: CLASSIFICATION
#     random_seed: 123456
#     pure_serving_model: false
#     [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#       num_trees: 300
#       decision_tree {
#         max_depth: 6
#         min_examples: 5
#         in_split_min_examples_check: true
#         keep_non_leaf_label_distribution: true
#         num_candidate_attributes: -1
#         missing_value_policy: GLOBAL_IMPUTATION
#         allow_na_conditions: false
#         categorical_set_greedy_forward {
#           sampling: 0.1
#           max_num_items: -1
#           min_item_frequency: 1
#         }
#         growing_strategy_local {
#         }
#         categorical {
#           cart {
#           }
#         }
#         axis_aligned_split {
#         }
#         internal {
#           sorting_strategy: PRESORTED
#         }
#         uplift {
#           min_examples_in_treatment: 5
#           split_score: KULLBACK_LEIBLER
#         }
#         numerical_vector_sequence {
#           max_num_test_examples: 1000
#           num_random_selected_anchors: 100
#         }
#       }
#       shrinkage: 0.1
#       loss: DEFAULT
#       validation_set_ratio: 0.1
#       validation_interval_in_trees: 1
#       early_stopping: VALIDATION_LOSS_INCREASE
#       early_stopping_num_trees_look_ahead: 30
#       l2_regularization: 0
#       lambda_loss: 1
#       mart {
#       }
#       adapt_subsample_for_maximum_training_duration: false
#       l1_regularization: 0
#       use_hessian_gain: false
#       l2_regularization_categorical: 1
#       xe_ndcg {
#         ndcg_truncation: 5
#       }
#       stochastic_gradient_boosting {
#         ratio: 1
#       }
#       apply_link_function: true
#       compute_permutation_variable_importance: false
#       early_stopping_initial_iteration: 10
#     }
#   }
#   optimizer {
#     optimizer_key: "RANDOM"
#     [yggdrasil_decision_forests.model.hyperparameters_optimizer_v2.proto.random] {
#       num_trials: 300
#     }
#   }
#   search_space {
#     fields {
#       name: "min_examples"
#       discrete_candidates {
#         possible_values {
#           integer: 2
#         }
#         possible_values {
#           integer: 5
#         }
#         possible_values {
#           integer: 7
#         }
#         possible_values {
#           integer: 10
#         }
#       }
#     }
#     fields {
#       name: "categorical_algorithm"
#       discrete_candidates {
#         possible_values {
#           categorical: "CART"
#         }
#         possible_values {
#           categorical: "RANDOM"
#         }
#       }
#     }
#     fields {
#       name: "growing_strategy"
#       discrete_candidates {
#         possible_values {
#           categorical: "LOCAL"
#         }
#         possible_values {
#           categorical: "BEST_FIRST_GLOBAL"
#         }
#       }
#       children {
#         name: "max_depth"
#         discrete_candidates {
#           possible_values {
#             integer: 3
#           }
#           possible_values {
#             integer: 4
#           }
#           possible_values {
#             integer: 5
#           }
#           possible_values {
#             integer: 6
#           }
#           possible_values {
#             integer: 8
#           }
#         }
#         parent_discrete_values {
#           possible_values {
#             categorical: "LOCAL"
#           }
#         }
#       }
#       children {
#         name: "max_num_nodes"
#         discrete_candidates {
#           possible_values {
#             integer: 16
#           }
#           possible_values {
#             integer: 32
#           }
#           possible_values {
#             integer: 64
#           }
#           possible_values {
#             integer: 128
#           }
#           possible_values {
#             integer: 256
#           }
#         }
#         parent_discrete_values {
#           possible_values {
#             categorical: "BEST_FIRST_GLOBAL"
#           }
#         }
#       }
#     }
#     fields {
#       name: "shrinkage"
#       discrete_candidates {
#         possible_values {
#           real: 0.02
#         }
#         possible_values {
#           real: 0.05
#         }
#         possible_values {
#           real: 0.1
#         }
#         possible_values {
#           real: 0.15
#         }
#       }
#     }
#     fields {
#       name: "num_candidate_attributes_ratio"
#       discrete_candidates {
#         possible_values {
#           real: 0.2
#         }
#         possible_values {
#           real: 0.5
#         }
#         possible_values {
#           real: 0.9
#         }
#         possible_values {
#           real: 1
#         }
#       }
#     }
#     fields {
#       name: "split_axis"
#       discrete_candidates {
#         possible_values {
#           categorical: "AXIS_ALIGNED"
#         }
#         possible_values {
#           categorical: "SPARSE_OBLIQUE"
#         }
#       }
#       children {
#         name: "sparse_oblique_normalization"
#         discrete_candidates {
#           possible_values {
#             categorical: "NONE"
#           }
#           possible_values {
#             categorical: "STANDARD_DEVIATION"
#           }
#           possible_values {
#             categorical: "MIN_MAX"
#           }
#         }
#         parent_discrete_values {
#           possible_values {
#             categorical: "SPARSE_OBLIQUE"
#           }
#         }
#       }
#       children {
#         name: "sparse_oblique_weights"
#         discrete_candidates {
#           possible_values {
#             categorical: "BINARY"
#           }
#           possible_values {
#             categorical: "CONTINUOUS"
#           }
#         }
#         parent_discrete_values {
#           possible_values {
#             categorical: "SPARSE_OBLIQUE"
#           }
#         }
#       }
#       children {
#         name: "sparse_oblique_num_projections_exponent"
#         discrete_candidates {
#           possible_values {
#             real: 1
#           }
#           possible_values {
#             real: 1.5
#           }
#         }
#         parent_discrete_values {
#           possible_values {
#             categorical: "SPARSE_OBLIQUE"
#           }
#         }
#       }
#     }
#   }
#   base_learner_deployment {
#     num_threads: 1
#   }
# }
#
# I0000 00:00:1764070092.862842    2741 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmpg5m654ph/working_cache"
# num_threads: 4
# try_resume_training: true
#
# I0000 00:00:1764070092.862983    3446 kernel.cc:895] Train model
# I0000 00:00:1764070092.863476    3446 hyperparameters_optimizer.cc:210] Hyperparameter search space:
# fields {
#   name: "min_examples"
#   discrete_candidates {
#     possible_values {
#       integer: 2
#     }
#     possible_values {
#       integer: 5
#     }
#     possible_values {
#       integer: 7
#     }
#     possible_values {
#       integer: 10
#     }
#   }
# }
# fields {
#   name: "categorical_algorithm"
#   discrete_candidates {
#     possible_values {
#       categorical: "CART"
#     }
#     possible_values {
#       categorical: "RANDOM"
#     }
#   }
# }
# fields {
#   name: "growing_strategy"
#   discrete_candidates {
#     possible_values {
#       categorical: "LOCAL"
#     }
#     possible_values {
#       categorical: "BEST_FIRST_GLOBAL"
#     }
#   }
#   children {
#     name: "max_depth"
#     discrete_candidates {
#       possible_values {
#         integer: 3
#       }
#       possible_values {
#         integer: 4
#       }
#       possible_values {
#         integer: 5
#       }
#       possible_values {
#         integer: 6
#       }
#       possible_values {
#         integer: 8
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "LOCAL"
#       }
#     }
#   }
#   children {
#     name: "max_num_nodes"
#     discrete_candidates {
#       possible_values {
#         integer: 16
#       }
#       possible_values {
#         integer: 32
#       }
#       possible_values {
#         integer: 64
#       }
#       possible_values {
#         integer: 128
#       }
#       possible_values {
#         integer: 256
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "BEST_FIRST_GLOBAL"
#       }
#     }
#   }
# }
# fields {
#   name: "shrinkage"
#   discrete_candidates {
#     possible_values {
#       real: 0.02
#     }
#     possible_values {
#       real: 0.05
#     }
#     possible_values {
#       real: 0.1
#     }
#     possible_values {
#       real: 0.15
#     }
#   }
# }
# fields {
#   name: "num_candidate_attributes_ratio"
#   discrete_candidates {
#     possible_values {
#       real: 0.2
#     }
#     possible_values {
#       real: 0.5
#     }
#     possible_values {
#       real: 0.9
#     }
#     possible_values {
#       real: 1
#     }
#   }
# }
# fields {
#   name: "split_axis"
#   discrete_candidates {
#     possible_values {
#       categorical: "AXIS_ALIGNED"
#     }
#     possible_values {
#       categorical: "SPARSE_OBLIQUE"
#     }
#   }
#   children {
#     name: "sparse_oblique_normalization"
#     discrete_candidates {
#       possible_values {
#         categorical: "NONE"
#       }
#       possible_values {
#         categorical: "STANDARD_DEVIATION"
#       }
#       possible_values {
#         categorical: "MIN_MAX"
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "SPARSE_OBLIQUE"
#       }
#     }
#   }
#   children {
#     name: "sparse_oblique_weights"
#     discrete_candidates {
#       possible_values {
#         categorical: "BINARY"
#       }
#       possible_values {
#         categorical: "CONTINUOUS"
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "SPARSE_OBLIQUE"
#       }
#     }
#   }
#   children {
#     name: "sparse_oblique_num_projections_exponent"
#     discrete_candidates {
#       possible_values {
#         real: 1
#       }
#       possible_values {
#         real: 1.5
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "SPARSE_OBLIQUE"
#       }
#     }
#   }
# }
#
# I0000 00:00:1764070092.863634    3446 hyperparameters_optimizer.cc:494] Start local tuner with 1 parallel trial(s), each with 4 thread(s)
# I0000 00:00:1764070092.866040    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070092.866071    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070092.866756    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070092.866891    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070092.872854    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.277561 train-accuracy:0.612469 valid-loss:1.250665 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070092.879308    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.225028 train-accuracy:0.612469 valid-loss:1.204589 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070093.348397    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.744452
# I0000 00:00:1764070093.348459    3447 gradient_boosted_trees.cc:279] Truncates the model to 48 tree(s) i.e. 48  iteration(s).
# I0000 00:00:1764070093.348905    3447 gradient_boosted_trees.cc:341] Final model num-trees:48 valid-loss:0.744452 valid-accuracy:0.863014
# I0000 00:00:1764070093.350694    3446 hyperparameters_optimizer.cc:578] [1/300] Score: -0.744452 / -0.744452 HParams: fields { name: "min_examples" value { integer: 2 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 32 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070093.350982    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070093.351010    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070093.351521    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070093.351613    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070093.355695    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.287338 train-accuracy:0.612469 valid-loss:1.247325 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070093.359926    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.239212 train-accuracy:0.612469 valid-loss:1.206982 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1764070093.633675    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.750476
# I0000 00:00:1764070093.633727    3447 gradient_boosted_trees.cc:279] Truncates the model to 43 tree(s) i.e. 43  iteration(s).
# I0000 00:00:1764070093.633958    3447 gradient_boosted_trees.cc:341] Final model num-trees:43 valid-loss:0.750476 valid-accuracy:0.821918
# I0000 00:00:1764070093.635140    3446 hyperparameters_optimizer.cc:578] [2/300] Score: -0.750476 / -0.744452 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 6 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.2 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070093.635989    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070093.636018    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070093.636544    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070093.636653    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070093.639287    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.282223 train-accuracy:0.612469 valid-loss:1.243266 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070093.642153    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.236380 train-accuracy:0.612469 valid-loss:1.200471 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1764070093.845150    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.74369
# I0000 00:00:1764070093.845198    3447 gradient_boosted_trees.cc:279] Truncates the model to 50 tree(s) i.e. 50  iteration(s).
# I0000 00:00:1764070093.845375    3447 gradient_boosted_trees.cc:341] Final model num-trees:50 valid-loss:0.743690 valid-accuracy:0.849315
# I0000 00:00:1764070093.847690    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070093.847730    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070093.847725    3446 hyperparameters_optimizer.cc:578] [3/300] Score: -0.74369 / -0.74369 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 6 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1764070093.848357    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070093.848450    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070093.853139    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.183005 train-accuracy:0.612469 valid-loss:1.149631 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070093.858362    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.070302 train-accuracy:0.820293 valid-loss:1.047379 valid-accuracy:0.835616 [total:0.01s iter:0.01s]
# I0000 00:00:1764070094.065940    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.758001
# I0000 00:00:1764070094.065980    3447 gradient_boosted_trees.cc:279] Truncates the model to 13 tree(s) i.e. 13  iteration(s).
# I0000 00:00:1764070094.066268    3447 gradient_boosted_trees.cc:341] Final model num-trees:13 valid-loss:0.758001 valid-accuracy:0.849315
# I0000 00:00:1764070094.066972    3446 hyperparameters_optimizer.cc:578] [4/300] Score: -0.758001 / -0.74369 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 16 } } fields { name: "shrinkage" value { real: 0.15 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070094.067566    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070094.067587    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070094.068645    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070094.068812    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070094.071105    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.298699 train-accuracy:0.612469 valid-loss:1.257471 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070094.073191    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.272624 train-accuracy:0.612469 valid-loss:1.230779 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070094.307106    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.730415
# I0000 00:00:1764070094.307140    3447 gradient_boosted_trees.cc:279] Truncates the model to 111 tree(s) i.e. 111  iteration(s).
# I0000 00:00:1764070094.307180    3447 gradient_boosted_trees.cc:341] Final model num-trees:111 valid-loss:0.730415 valid-accuracy:0.835616
# I0000 00:00:1764070094.308412    3446 hyperparameters_optimizer.cc:578] [5/300] Score: -0.730415 / -0.730415 HParams: fields { name: "min_examples" value { integer: 2 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 3 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070094.308592    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070094.308624    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070094.309187    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070094.309304    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070094.312434    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.278469 train-accuracy:0.612469 valid-loss:1.240387 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070094.315670    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.226048 train-accuracy:0.612469 valid-loss:1.205748 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1764070094.509955    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.752799
# I0000 00:00:1764070094.509982    3447 gradient_boosted_trees.cc:279] Truncates the model to 33 tree(s) i.e. 33  iteration(s).
# I0000 00:00:1764070094.510459    3447 gradient_boosted_trees.cc:341] Final model num-trees:33 valid-loss:0.752799 valid-accuracy:0.849315
# I0000 00:00:1764070094.511898    3446 hyperparameters_optimizer.cc:578] [6/300] Score: -0.752799 / -0.730415 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 128 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1764070094.512875    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070094.512919    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070094.513452    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070094.513573    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070094.519292    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.279438 train-accuracy:0.612469 valid-loss:1.242180 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070094.525472    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.228260 train-accuracy:0.612469 valid-loss:1.203458 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070094.912301    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.748012
# I0000 00:00:1764070094.912333    3447 gradient_boosted_trees.cc:279] Truncates the model to 37 tree(s) i.e. 37  iteration(s).
# I0000 00:00:1764070094.912798    3447 gradient_boosted_trees.cc:341] Final model num-trees:37 valid-loss:0.748012 valid-accuracy:0.849315
# I0000 00:00:1764070094.914246    3446 hyperparameters_optimizer.cc:578] [7/300] Score: -0.748012 / -0.730415 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 64 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070094.915239    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070094.915278    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070094.915869    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070094.916002    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070094.917768    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.319099 train-accuracy:0.612469 valid-loss:1.276812 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070094.919476    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.303195 train-accuracy:0.612469 valid-loss:1.261046 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070095.309900    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.74398
# I0000 00:00:1764070095.309940    3447 gradient_boosted_trees.cc:279] Truncates the model to 190 tree(s) i.e. 190  iteration(s).
# I0000 00:00:1764070095.309980    3447 gradient_boosted_trees.cc:341] Final model num-trees:190 valid-loss:0.743980 valid-accuracy:0.835616
# I0000 00:00:1764070095.310785    3446 hyperparameters_optimizer.cc:578] [8/300] Score: -0.74398 / -0.730415 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 3 } } fields { name: "shrinkage" value { real: 0.02 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070095.311569    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070095.311607    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070095.312188    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070095.312304    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070095.318171    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.217811 train-accuracy:0.612469 valid-loss:1.204549 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070095.324306    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.115039 train-accuracy:0.744499 valid-loss:1.119043 valid-accuracy:0.726027 [total:0.01s iter:0.01s]
# I0000 00:00:1764070095.631910    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.793881
# I0000 00:00:1764070095.631943    3447 gradient_boosted_trees.cc:279] Truncates the model to 20 tree(s) i.e. 20  iteration(s).
# I0000 00:00:1764070095.632518    3447 gradient_boosted_trees.cc:341] Final model num-trees:20 valid-loss:0.793881 valid-accuracy:0.835616
# I0000 00:00:1764070095.633685    3446 hyperparameters_optimizer.cc:578] [9/300] Score: -0.793881 / -0.730415 HParams: fields { name: "min_examples" value { integer: 2 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 128 } } fields { name: "shrinkage" value { real: 0.1 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070095.634477    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070095.634499    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070095.635050    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070095.635169    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070095.637528    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.186697 train-accuracy:0.612469 valid-loss:1.170354 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070095.639921    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.076922 train-accuracy:0.804401 valid-loss:1.078076 valid-accuracy:0.767123 [total:0.00s iter:0.00s]
# I0000 00:00:1764070095.825752    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.740361
# I0000 00:00:1764070095.825782    3447 gradient_boosted_trees.cc:279] Truncates the model to 52 tree(s) i.e. 52  iteration(s).
# I0000 00:00:1764070095.826154    3447 gradient_boosted_trees.cc:341] Final model num-trees:52 valid-loss:0.740361 valid-accuracy:0.876712
# I0000 00:00:1764070095.827671    3446 hyperparameters_optimizer.cc:578] [10/300] Score: -0.740361 / -0.730415 HParams: fields { name: "min_examples" value { integer: 5 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 32 } } fields { name: "shrinkage" value { real: 0.15 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.2 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1764070095.828700    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070095.828746    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070095.829272    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070095.829386    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070095.834735    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.313300 train-accuracy:0.612469 valid-loss:1.275865 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070095.839898    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.291908 train-accuracy:0.612469 valid-loss:1.254709 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070096.567062    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.770632
# I0000 00:00:1764070096.567110    3447 gradient_boosted_trees.cc:279] Truncates the model to 116 tree(s) i.e. 116  iteration(s).
# I0000 00:00:1764070096.567553    3447 gradient_boosted_trees.cc:341] Final model num-trees:116 valid-loss:0.770632 valid-accuracy:0.835616
# I0000 00:00:1764070096.571979    3446 hyperparameters_optimizer.cc:578] [11/300] Score: -0.770632 / -0.730415 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 128 } } fields { name: "shrinkage" value { real: 0.02 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070096.574085    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070096.574128    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070096.574683    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070096.574833    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070096.580672    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.217697 train-accuracy:0.612469 valid-loss:1.194637 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070096.586025    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.127283 train-accuracy:0.765281 valid-loss:1.118487 valid-accuracy:0.767123 [total:0.01s iter:0.01s]
# I0000 00:00:1764070096.935486    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.726985
# I0000 00:00:1764070096.935537    3447 gradient_boosted_trees.cc:279] Truncates the model to 32 tree(s) i.e. 32  iteration(s).
# I0000 00:00:1764070096.936024    3447 gradient_boosted_trees.cc:341] Final model num-trees:32 valid-loss:0.726985 valid-accuracy:0.849315
# I0000 00:00:1764070096.937989    3446 hyperparameters_optimizer.cc:578] [12/300] Score: -0.726985 / -0.726985 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 64 } } fields { name: "shrinkage" value { real: 0.1 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070096.938160    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070096.938201    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070096.938788    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070096.938902    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070096.945541    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.272988 train-accuracy:0.612469 valid-loss:1.238339 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070096.953062    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.215197 train-accuracy:0.612469 valid-loss:1.199493 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070097.563814    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.720019
# I0000 00:00:1764070097.563869    3447 gradient_boosted_trees.cc:279] Truncates the model to 53 tree(s) i.e. 53  iteration(s).
# I0000 00:00:1764070097.564453    3447 gradient_boosted_trees.cc:341] Final model num-trees:53 valid-loss:0.720019 valid-accuracy:0.849315
# I0000 00:00:1764070097.568757    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070097.568798    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070097.568785    3446 hyperparameters_optimizer.cc:578] [13/300] Score: -0.720019 / -0.720019 HParams: fields { name: "min_examples" value { integer: 5 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 8 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070097.569357    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070097.569472    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070097.574395    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.280944 train-accuracy:0.612469 valid-loss:1.241659 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070097.579071    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.233565 train-accuracy:0.612469 valid-loss:1.201183 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1764070097.927551    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.754332
# I0000 00:00:1764070097.927586    3447 gradient_boosted_trees.cc:279] Truncates the model to 46 tree(s) i.e. 46  iteration(s).
# I0000 00:00:1764070097.927837    3447 gradient_boosted_trees.cc:341] Final model num-trees:46 valid-loss:0.754332 valid-accuracy:0.821918
# I0000 00:00:1764070097.928874    3446 hyperparameters_optimizer.cc:578] [14/300] Score: -0.754332 / -0.720019 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 16 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070097.929657    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070097.929694    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070097.930275    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070097.930920    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070097.931475    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.296600 train-accuracy:0.612469 valid-loss:1.257550 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070097.932188    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.262156 train-accuracy:0.612469 valid-loss:1.225177 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070097.999513    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.747695
# I0000 00:00:1764070097.999543    3447 gradient_boosted_trees.cc:279] Truncates the model to 77 tree(s) i.e. 77  iteration(s).
# I0000 00:00:1764070097.999575    3447 gradient_boosted_trees.cc:341] Final model num-trees:77 valid-loss:0.747695 valid-accuracy:0.849315
# I0000 00:00:1764070097.999901    3446 hyperparameters_optimizer.cc:578] [15/300] Score: -0.747695 / -0.720019 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 3 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "AXIS_ALIGNED" } }
# I0000 00:00:1764070098.000481    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070098.000509    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070098.001076    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070098.001594    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070098.003681    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.178774 train-accuracy:0.612469 valid-loss:1.158014 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# ...
# I0000 00:00:1764070177.539309    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070177.539385    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070177.540086    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070177.540180    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070177.546435    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.179277 train-accuracy:0.612469 valid-loss:1.147190 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1764070177.553743    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.056309 train-accuracy:0.834963 valid-loss:1.041788 valid-accuracy:0.835616 [total:0.01s iter:0.01s]
# I0000 00:00:1764070177.838655    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.75167
# I0000 00:00:1764070177.838691    3447 gradient_boosted_trees.cc:279] Truncates the model to 16 tree(s) i.e. 16  iteration(s).
# I0000 00:00:1764070177.839127    3447 gradient_boosted_trees.cc:341] Final model num-trees:16 valid-loss:0.751670 valid-accuracy:0.835616
# I0000 00:00:1764070177.840087    3446 hyperparameters_optimizer.cc:578] [295/300] Score: -0.75167 / -0.689191 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 256 } } fields { name: "shrinkage" value { real: 0.15 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1764070177.840689    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070177.840753    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070177.841306    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070177.841869    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070177.844155    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.170375 train-accuracy:0.612469 valid-loss:1.155466 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070177.846856    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.051501 train-accuracy:0.833741 valid-loss:1.053374 valid-accuracy:0.821918 [total:0.00s iter:0.00s]
# I0000 00:00:1764070177.951361    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.719954
# I0000 00:00:1764070177.951386    3447 gradient_boosted_trees.cc:279] Truncates the model to 16 tree(s) i.e. 16  iteration(s).
# I0000 00:00:1764070177.951758    3447 gradient_boosted_trees.cc:341] Final model num-trees:16 valid-loss:0.719954 valid-accuracy:0.849315
# I0000 00:00:1764070177.952393    3446 hyperparameters_optimizer.cc:578] [296/300] Score: -0.719954 / -0.689191 HParams: fields { name: "min_examples" value { integer: 2 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 32 } } fields { name: "shrinkage" value { real: 0.15 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "AXIS_ALIGNED" } }
# I0000 00:00:1764070177.952844    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070177.952866    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070177.953357    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070177.953444    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070177.956662    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.177788 train-accuracy:0.612469 valid-loss:1.148158 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070177.959735    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.068148 train-accuracy:0.820293 valid-loss:1.055208 valid-accuracy:0.835616 [total:0.01s iter:0.00s]
# I0000 00:00:1764070178.076325    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.779479
# I0000 00:00:1764070178.076357    3447 gradient_boosted_trees.cc:279] Truncates the model to 15 tree(s) i.e. 15  iteration(s).
# I0000 00:00:1764070178.076758    3447 gradient_boosted_trees.cc:341] Final model num-trees:15 valid-loss:0.779479 valid-accuracy:0.849315
# I0000 00:00:1764070178.077592    3446 hyperparameters_optimizer.cc:578] [297/300] Score: -0.779479 / -0.689191 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 128 } } fields { name: "shrinkage" value { real: 0.15 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "NONE" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1764070178.078128    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070178.078166    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070178.078688    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070178.078818    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070178.081817    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.177798 train-accuracy:0.612469 valid-loss:1.182589 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070178.084769    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.061332 train-accuracy:0.821516 valid-loss:1.082044 valid-accuracy:0.794521 [total:0.01s iter:0.00s]
# I0000 00:00:1764070178.222300    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.771231
# I0000 00:00:1764070178.222328    3447 gradient_boosted_trees.cc:279] Truncates the model to 22 tree(s) i.e. 22  iteration(s).
# I0000 00:00:1764070178.222639    3447 gradient_boosted_trees.cc:341] Final model num-trees:22 valid-loss:0.771231 valid-accuracy:0.835616
# I0000 00:00:1764070178.223548    3446 hyperparameters_optimizer.cc:578] [298/300] Score: -0.771231 / -0.689191 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 128 } } fields { name: "shrinkage" value { real: 0.15 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "NONE" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1764070178.224145    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070178.224190    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070178.224698    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070178.224818    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070178.226838    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.199803 train-accuracy:0.612469 valid-loss:1.161839 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070178.228633    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.100978 train-accuracy:0.800734 valid-loss:1.059287 valid-accuracy:0.808219 [total:0.00s iter:0.00s]
# I0000 00:00:1764070178.316777    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.758888
# I0000 00:00:1764070178.316803    3447 gradient_boosted_trees.cc:279] Truncates the model to 16 tree(s) i.e. 16  iteration(s).
# I0000 00:00:1764070178.316904    3447 gradient_boosted_trees.cc:341] Final model num-trees:16 valid-loss:0.758888 valid-accuracy:0.876712
# I0000 00:00:1764070178.317315    3446 hyperparameters_optimizer.cc:578] [299/300] Score: -0.758888 / -0.689191 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 5 } } fields { name: "shrinkage" value { real: 0.15 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "NONE" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1764070178.317746    3447 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1764070178.317766    3447 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 14 feature(s).
# I0000 00:00:1764070178.318269    3447 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1764070178.318352    3447 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1764070178.321481    3447 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.313155 train-accuracy:0.612469 valid-loss:1.275030 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1764070178.323994    3447 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.293813 train-accuracy:0.612469 valid-loss:1.259204 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1764070178.680597    3447 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.749156
# I0000 00:00:1764070178.680638    3447 gradient_boosted_trees.cc:279] Truncates the model to 103 tree(s) i.e. 103  iteration(s).
# I0000 00:00:1764070178.681122    3447 gradient_boosted_trees.cc:341] Final model num-trees:103 valid-loss:0.749156 valid-accuracy:0.849315
# I0000 00:00:1764070178.684588    3446 hyperparameters_optimizer.cc:578] [300/300] Score: -0.749156 / -0.689191 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 128 } } fields { name: "shrinkage" value { real: 0.02 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "NONE" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1764070178.687433    3446 hyperparameters_optimizer.cc:219] Best hyperparameters:
# fields {
#   name: "min_examples"
#   value {
#     integer: 5
#   }
# }
# fields {
#   name: "categorical_algorithm"
#   value {
#     categorical: "CART"
#   }
# }
# fields {
#   name: "growing_strategy"
#   value {
#     categorical: "BEST_FIRST_GLOBAL"
#   }
# }
# fields {
#   name: "max_num_nodes"
#   value {
#     integer: 32
#   }
# }
# fields {
#   name: "shrinkage"
#   value {
#     real: 0.1
#   }
# }
# fields {
#   name: "num_candidate_attributes_ratio"
#   value {
#     real: 0.2
#   }
# }
# fields {
#   name: "split_axis"
#   value {
#     categorical: "SPARSE_OBLIQUE"
#   }
# }
# fields {
#   name: "sparse_oblique_normalization"
#   value {
#     categorical: "NONE"
#   }
# }
# fields {
#   name: "sparse_oblique_weights"
#   value {
#     categorical: "BINARY"
#   }
# }
# fields {
#   name: "sparse_oblique_num_projections_exponent"
#   value {
#     real: 1
#   }
# }
#
# I0000 00:00:1764070178.689405    3446 kernel.cc:926] Export model in log directory: /tmp/tmpg5m654ph with prefix 0596821591cb4d5f
# I0000 00:00:1764070178.692886    3446 kernel.cc:944] Save model in resources
# I0000 00:00:1764070178.695301    2741 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.689191
#
# Accuracy: 0.863014  CI95[W][0 1]
# ErrorRate: : 0.136986
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  41   7
# 2   3  22
# Total: 73
#
#
# I0000 00:00:1764070178.719131    2741 decision_forest.cc:808] Model loaded with 25 root(s), 1543 node(s), and 12 input feature(s).
# I0000 00:00:1764070178.719160    2741 abstract_model.cc:1439] Engine "GradientBoostedTreesGeneric" built
# WARNING:tensorflow:6 out of the last 6 calls to <function InferenceCoreModel.make_predict_function.<locals>.predict_function_trained at 0x78dcb8d725c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function InferenceCoreModel.make_predict_function.<locals>.predict_function_trained at 0x78dcb8d725c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
tuned_self_evaluation = tuned_model.make_inspector().evaluation()
print(f"Accuracy: {tuned_self_evaluation.accuracy} Loss:{tuned_self_evaluation.loss}")
# Out:
# Accuracy: 0.8630136847496033 Loss:0.6891911029815674
